# %% [markdown]
# # Aula 4: Pacote para dados tabulares

# %% [markdown]
# ### Material de apoio:
#
# - Livro online com exemplos e descrições sobre numpy, matplotlib e pandas: https://jakevdp.github.io/PythonDataScienceHandbook/
# - Guia do usuário de Pandas: https://pandas.pydata.org/pandas-docs/stable/user_guide/

# %% [markdown]
# ## Pandas: Pacote para dados tabulares
#
# - pacote para analisar dados tabulares
# - muito utilizado para análise de séries temporais
# - ciência de dados, aprendizado de máquina? Tem pandas!

# %% [markdown]
# **O que são dados tabulares?**
#
# - dados estruturados
# - colunas representam variáveis
# - linhas são informações destas variáveis (observações/medições)
# - compartilham o mesmo índice
# - formatos:
#
# ![image.png](attachment:image.png)
#
# Fonte: Getting started do Pandas - https://pandas.pydata.org/docs/getting_started/index.html#getting-started

# %% [markdown]
# Conceitos importantes para utilizar o pandas
#
# - Series: matriz 1D com um índice definido (perfil vertical)
#
# - DataFrame: matriz 2D, com eixos rotulados que compartilham o mesmo índice (perfis vertical)
#
# - Eixos: axis == 0 (rows) e axis == 1 (cols)
#
# ![image.png](attachment:image.png)
#
# Fonte: Getting started do Pandas - https://pandas.pydata.org/docs/getting_started/index.html#getting-started

# %% [markdown]
# ## Vamos ver algumas funcionalidade básicas
#
# Criando objetos (Series e DataFrame):
#
# - `data` para indicar os dados que serão armazenados na estrutura e
# - `index` para apontar o indexamento que eles terão.

# %%
# linhas de códigos para evitar Warnings. Uso apenas para apresentações com o RISE para não ocupar espaço demais
# na tela.
import warnings
warnings.filterwarnings('ignore')

# %%
# padrão de importação
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# criando um pd.Series
sr = pd.Series(data=np.random.randn(5), index=np.arange(0,5))

# criando um pd.DataFrame: notem o F maiúsculo
df = pd.DataFrame(data={'serie1': sr, 
                        'serie2': np.random.randn(5)},
                  
                  index=np.arange(0,5))
df
# Out:
#      serie1    serie2
# 0  0.764149  0.555254
# 1  0.457404 -0.046930
# 2  1.051885 -1.329986
# 3  0.597480 -0.641632
# 4 -0.639051 -1.775738

# %% [markdown]
# No entanto, é comum utilizar dicionários para criar DataFrame, pois podemos indicar também qual o nome de cada coluna (cabeçalho, header), ao passo que em Series não temos esta possibilidade:

# %%
pd.DataFrame(data={'coluna1': np.random.randn(10)}, index=range(10))
# Out:
#     coluna1
# 0 -0.108645
# 1 -0.171611
# 2  0.331107
# 3  0.007496
# 4  0.579086
# 5 -1.246458
# 6  2.070942
# 7 -0.285247
# 8 -0.857920
# 9 -0.652300

# %% [markdown]
# Utiliza-se o **pandas** para leitura de arquivos csv e planilhas excel, estruturando estes arquivos em um DataFrame organizado.

# %% [markdown]
# ###  Revisitando aquele perfil de praia que ficou de exercício da aula passada
#
# - retomando o conjunto de dados utilizados na aula anterior
# - inserir em um Dataframe

# %%
perfil = np.loadtxt('../Dados/Perfil.csv', delimiter=',')
# perfil

# %%
# lista com com nomes que vamos dar as nossas colunas
colunas = ['Altura', 'Comprimento']
# lendo arquivo
df_perfil = pd.read_csv('../Dados/Perfil.csv', sep=',',
                      header=None, index_col=None, names=colunas)

df_perfil
# Out:
#       Altura  Comprimento
# 0   2.459516     0.000000
# 1   2.430612    12.483312
# 2   2.361571    24.966625
# 3   2.253177    37.449937
# 4   2.137680    49.933250
# 5   2.031411    62.416562
# 6   1.950376    74.899874
# 7   1.909881    87.383187
# 8   1.843392    99.866499
# 9   1.742976   112.349812
# 10  1.626083   124.833124
# 11  1.481231   137.316437
# 12  1.318158   149.799749
# 13  1.152340   162.283061
# 14  0.946220   174.766374
# 15  0.671221   187.249686
# 16  0.474435   199.732999
# 17  0.298907   212.216311
# 18  0.127439   224.699623
# 19  0.010936   237.182936
# 20 -0.027960   249.666248

# %% [markdown]
# ### Seleção de dados por rótulo e por posição
#
# Motivos:
#
# - explorar
# - limpar
#
# Como:
#
# - `.loc[row, col]`
# - `.iloc[nrow, ncol]`

# %% [markdown]
# Exemplos:

# %%
# o primeiro item deve ser a linha (neste caso todas)
# o segundo deve ser o nome das colunas
df_perfil.loc[:, ['Altura']]
# Out:
#       Altura
# 0   2.459516
# 1   2.430612
# 2   2.361571
# 3   2.253177
# 4   2.137680
# 5   2.031411
# 6   1.950376
# 7   1.909881
# 8   1.843392
# 9   1.742976
# 10  1.626083
# 11  1.481231
# 12  1.318158
# 13  1.152340
# 14  0.946220
# 15  0.671221
# 16  0.474435
# 17  0.298907
# 18  0.127439
# 19  0.010936
# 20 -0.027960

# %%
# acessar as informações por índices numéricos, tal qual o numpy
df_perfil.iloc[0,0] # 2.45
# Out:
# 2.4595159107900004

# %%
# podemos configurar um index novo e argumento novo!
df_perfil.set_index('Comprimento', inplace=True)

# %%
# e podemos resetar o indice também
df_perfil.reset_index(inplace=False)
# Out:
#     Comprimento    Altura     media
# 0      0.000000  2.459516  2.459516
# 1     12.483312  2.430612  2.430612
# 2     24.966625  2.361571  2.361571
# 3     37.449937  2.253177  2.253177
# 4     49.933250  2.137680  2.137680
# 5     62.416562  2.031411  2.031411
# 6     74.899874  1.950376  1.950376
# 7     87.383187  1.909881  1.909881
# 8     99.866499  1.843392  1.843392
# 9    112.349812  1.742976  1.742976
# 10   124.833124  1.626083  1.626083
# 11   137.316437  1.481231  1.481231
# 12   149.799749  1.318158  1.318158
# 13   162.283061  1.152340  1.152340
# 14   174.766374  0.946220  0.946220
# 15   187.249686  0.671221  0.671221
# 16   199.732999  0.474435  0.474435
# 17   212.216311  0.298907  0.298907
# 18   224.699623  0.127439  0.127439
# 19   237.182936  0.010936  0.010936
# 20   249.666248 -0.027960 -0.027960

# %% [markdown]
# ## Visualização de dados
#
# - integração Numpy e Matplotlib
# - acesso aos métodos
# - facilidade

# %%
import matplotlib.pyplot as plt
# plotando perfis verticais para Janeiro
ax = df_perfil.plot(y='Altura',
             title='Perfil de praia',
             fontsize=15,
             legend=True,
             figsize=(15,3))

# # adicionando titulo para o plot
# plt.title('Perfil praial - exercício de python', fontsize=25)

# # adicionando labels para os eixos das abssissas e das ordenadas
# plt.xlabel('Comprimento da praia (m)', fontsize=20)
# plt.ylabel('Altura da praia (m)', fontsize=20)

# # adicionando gradeamento
# plt.grid('--', alpha=.2)

# # adicionando legenda
# plt.legend(ncol=6, bbox_to_anchor=(.99, .99))

# infelizmente o pandas, ainda, não possui um argumento para inverter o eixo y
# plt.gca().invert_yaxis()

# %% [markdown]
# - nem sempre é tão benéfico usar pandas
# - visualização fácil durante análise exploratória
# - potencial em termos de análise estatística

# %% [markdown]
# Mas como nem tudo é um mar de rosas, precisamos muitas vezes limpar essa planilha, lidar com caracteres acentuados, etc.
#
# Vamos ver alguns casos, utilizando um arquivo csv de dados de terremoto.
#
# Os dados foram retirados da seguinte fonte: https://www.analyticsvidhya.com/blog/2021/05/seismic-analysis-with-python/

# %%
# se estiver no google colab, rode:
# !wget --directory-prefix=../dados/ https://raw.githubusercontent.com/nilodna/python-basico/feature_iojr-shortcourse/dados/pnboia_vitoria.csv
# Out:
# --2021-11-25 11:54:31--  https://raw.githubusercontent.com/nilodna/python-basico/feature_iojr-shortcourse/dados/pnboia_vitoria.csv
# Resolvendo raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.110.133, 185.199.111.133, ...
# Conectando-se a raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... conectado.
# A requisição HTTP foi enviada, aguardando resposta... 200 OK
# Tamanho: 4162501 (4,0M) [text/plain]
# Salvando em: “../dados/pnboia_vitoria.csv”
#
# pnboia_vitoria.csv  100%[===================>]   3,97M  1,93MB/s    em 2,1s
#
# 2021-11-25 11:54:34 (1,93 MB/s) - “../dados/pnboia_vitoria.csv” salvo [4162501/4162501]

# %%
# leitura do arquivo
df = pd.read_csv('../Dados/database.csv')

df
# Out:
#              Date      Time  Latitude  Longitude        Type   Depth  \
# 0      01/02/1965  13:44:18   19.2460   145.6160  Earthquake  131.60
# 1      01/04/1965  11:29:49    1.8630   127.3520  Earthquake   80.00
# 2      01/05/1965  18:05:58  -20.5790  -173.9720  Earthquake   20.00
# 3      01/08/1965  18:49:43  -59.0760   -23.5570  Earthquake   15.00
# 4      01/09/1965  13:32:50   11.9380   126.4270  Earthquake   15.00
# ...           ...       ...       ...        ...         ...     ...
# 23407  12/28/2016  08:22:12   38.3917  -118.8941  Earthquake   12.30
# 23408  12/28/2016  09:13:47   38.3777  -118.8957  Earthquake    8.80
# 23409  12/28/2016  12:38:51   36.9179   140.4262  Earthquake   10.00
# 23410  12/29/2016  22:30:19   -9.0283   118.6639  Earthquake   79.00
# 23411  12/30/2016  20:08:28   37.3973   141.4103  Earthquake   11.94
#
#        Depth Error  Depth Seismic Stations  Magnitude Magnitude Type  ...  \
# 0          -9999.0                 -9999.0        6.0             MW  ...
# 1          -9999.0                 -9999.0        5.8             MW  ...
# 2          -9999.0                 -9999.0        6.2             MW  ...
# 3          -9999.0                 -9999.0        5.8             MW  ...
# 4          -9999.0                 -9999.0        5.8             MW  ...
# ...            ...                     ...        ...            ...  ...
# 23407          1.2                    40.0        5.6             ML  ...
# 23408          2.0                    33.0        5.5             ML  ...
# 23409          1.8                 -9999.0        5.9            MWW  ...
# 23410          1.8                 -9999.0        6.3            MWW  ...
# 23411          2.2                 -9999.0        5.5             MB  ...
#
#        Magnitude Seismic Stations  Azimuthal Gap  Horizontal Distance  \
# 0                         -9999.0       -9999.00            -9999.000
# 1                         -9999.0       -9999.00            -9999.000
# 2                         -9999.0       -9999.00            -9999.000
# 3                         -9999.0       -9999.00            -9999.000
# 4                         -9999.0       -9999.00            -9999.000
# ...                           ...            ...                  ...
# 23407                        18.0          42.47                0.120
# 23408                        18.0          48.58                0.129
# 23409                     -9999.0          91.00                0.992
# 23410                     -9999.0          26.00                3.553
# 23411                       428.0          97.00                0.681
#
#        Horizontal Error  Root Mean Square            ID  Source  \
# 0               -9999.0        -9999.0000  ISCGEM860706  ISCGEM
# 1               -9999.0        -9999.0000  ISCGEM860737  ISCGEM
# 2               -9999.0        -9999.0000  ISCGEM860762  ISCGEM
# 3               -9999.0        -9999.0000  ISCGEM860856  ISCGEM
# 4               -9999.0        -9999.0000  ISCGEM860890  ISCGEM
# ...                 ...               ...           ...     ...
# 23407           -9999.0            0.1898    NN00570710      NN
# 23408           -9999.0            0.2187    NN00570744      NN
# 23409               4.8            1.5200    US10007NAF      US
# 23410               6.0            1.4300    US10007NL0      US
# 23411               4.5            0.9100    US10007NTD      US
#
#       Location Source Magnitude Source     Status
# 0              ISCGEM           ISCGEM  Automatic
# 1              ISCGEM           ISCGEM  Automatic
# 2              ISCGEM           ISCGEM  Automatic
# 3              ISCGEM           ISCGEM  Automatic
# 4              ISCGEM           ISCGEM  Automatic
# ...               ...              ...        ...
# 23407              NN               NN   Reviewed
# 23408              NN               NN   Reviewed
# 23409              US               US   Reviewed
# 23410              US               US   Reviewed
# 23411              US               US   Reviewed
#
# [23412 rows x 21 columns]

# %%
# descrição em termos estatísticos
df.describe()
# Out:
#            Latitude     Longitude         Depth   Depth Error  \
# count  23412.000000  23412.000000  23412.000000  23412.000000
# mean       1.679033     39.639961     70.767911  -8092.806027
# std       30.113183    125.511959    122.651898   3928.948942
# min      -77.080000   -179.997000     -1.100000  -9999.000000
# 25%      -18.653000    -76.349750     14.522500  -9999.000000
# 50%       -3.568500    103.982000     33.000000  -9999.000000
# 75%       26.190750    145.026250     54.000000  -9999.000000
# max       86.005000    179.998000    700.000000     91.295000
#
#        Depth Seismic Stations     Magnitude  Magnitude Error  \
# count            23412.000000  23412.000000     23412.000000
# mean             -6884.479156      5.882531     -9859.341001
# std               4723.177128      0.423066      1173.462629
# min              -9999.000000      5.500000     -9999.000000
# 25%              -9999.000000      5.600000     -9999.000000
# 50%              -9999.000000      5.700000     -9999.000000
# 75%                115.000000      6.000000     -9999.000000
# max                934.000000      9.100000         0.410000
#
#        Magnitude Seismic Stations  Azimuthal Gap  Horizontal Distance  \
# count                23412.000000   23412.000000         23412.000000
# mean                 -8898.584401   -6867.911216         -9313.676225
# std                   3137.969855    4652.264633          2527.032797
# min                  -9999.000000   -9999.000000         -9999.000000
# 25%                  -9999.000000   -9999.000000         -9999.000000
# 50%                  -9999.000000   -9999.000000         -9999.000000
# 75%                  -9999.000000      22.000000         -9999.000000
# max                    821.000000     360.000000            37.874000
#
#        Horizontal Error  Root Mean Square
# count      23412.000000      23412.000000
# mean       -9504.907135      -2587.399310
# std         2168.017307       4380.087952
# min        -9999.000000      -9999.000000
# 25%        -9999.000000      -9999.000000
# 50%        -9999.000000          0.930000
# 75%        -9999.000000          1.100000
# max           99.000000          3.440000

# %%
# informações em termos computacionais: tipo das colunas, nomes, quantidade de linhas, etc
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23412 entries, 0 to 23411
# Data columns (total 21 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Date                        23412 non-null  object
#  1   Time                        23412 non-null  object
#  2   Latitude                    23412 non-null  float64
#  3   Longitude                   23412 non-null  float64
#  4   Type                        23412 non-null  object
#  5   Depth                       23412 non-null  float64
#  6   Depth Error                 23412 non-null  float64
#  7   Depth Seismic Stations      23412 non-null  float64
#  8   Magnitude                   23412 non-null  float64
#  9   Magnitude Type              23412 non-null  object
#  10  Magnitude Error             23412 non-null  float64
#  11  Magnitude Seismic Stations  23412 non-null  float64
#  12  Azimuthal Gap               23412 non-null  float64
#  13  Horizontal Distance         23412 non-null  float64
#  14  Horizontal Error            23412 non-null  float64
#  15  Root Mean Square            23412 non-null  float64
#  16  ID                          23412 non-null  object
#  17  Source                      23412 non-null  object
#  18  Location Source             23412 non-null  object
#  19  Magnitude Source            23412 non-null  object
#  20  Status                      23412 non-null  object
# dtypes: float64(12), object(9)
# memory usage: 3.8+ MB

# %% [markdown]
# - temos muita informação neste conjunto
# - podemos selecionar estas informações durante a leitura do arquivo
# - explorar metadados

# %% [markdown]
# #### Opções durante leitura do arquivo
#
# - `skiprows`: pular, durante a leitura, uma quantidade de linhas
# - `sheet_name`: para ler uma aba específica de uma planilha excel
#
# - `sep`: qual o separador ou delimitador do arquivo (padrão ;)
#
# - `header`: qual linha deve ser utilizada para nomear colunas
# - `names`: nomear colunas manualmente
#
# - `usecols`: selecionar quais colunas devem ser lidas (utiliza-se números inteiros)
#
# - `index_col`: indicar qual coluna deve ser o índice
#
# - `encoding` (utf8 padrão e latin1 para ç à é î ã): para casos com caracteres acentuados
#
# - `decimal`: substitui virgulas por ponto, porém use com cautela!

# %%
df = pd.read_csv('../Dados/database.csv', 
                 usecols=[0,2,3,7], index_col=0,)

df.tail() # de forma análoga existe o .head()
# Out:
#             Latitude  Longitude  Depth Seismic Stations
# Date
# 12/28/2016   38.3917  -118.8941                    40.0
# 12/28/2016   38.3777  -118.8957                    33.0
# 12/28/2016   36.9179   140.4262                 -9999.0
# 12/29/2016   -9.0283   118.6639                 -9999.0
# 12/30/2016   37.3973   141.4103                 -9999.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 23412 entries, 01/02/1965 to 12/30/2016
# Data columns (total 3 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Latitude                23412 non-null  float64
#  1   Longitude               23412 non-null  float64
#  2   Depth Seismic Stations  23412 non-null  float64
# dtypes: float64(3)
# memory usage: 731.6+ KB

# %% [markdown]
# Em alguns casos, porém:
#
# - valores invalido possuem outro caracter (ex: -9999)
# - substituímos usando o método .replace()
# - inserimos np.nan no lugar

# %%
df = df.replace(-9999.0, np.nan)
df.tail() # porém é um float:
# Out:
#             Latitude  Longitude  Depth Seismic Stations
# Date
# 12/28/2016   38.3917  -118.8941                    40.0
# 12/28/2016   38.3777  -118.8957                    33.0
# 12/28/2016   36.9179   140.4262                     NaN
# 12/29/2016   -9.0283   118.6639                     NaN
# 12/30/2016   37.3973   141.4103                     NaN

# %%
print(np.nan)
type(np.nan)
# Out:
# nan
# float

# %% [markdown]
# ## Removendo dados
#
# - `.drop()`: remove dados específicos, indicando index/coluna

# %%
df.drop(['Depth Seismic Stations'], axis=1).head()
# Out:
#             Latitude  Longitude
# Date
# 01/02/1965    19.246    145.616
# 01/04/1965     1.863    127.352
# 01/05/1965   -20.579   -173.972
# 01/08/1965   -59.076    -23.557
# 01/09/1965    11.938    126.427

# %% [markdown]
# ## Removendo dados
#
# - `.drop()`: remove dados específicos, indicando index/coluna
# - `.dropna()`: remove valores faltantes (not-a-number)

# %%
df.dropna(axis=1, how='all')
# Out:
#             Latitude  Longitude  Depth Seismic Stations
# Date
# 01/02/1965   19.2460   145.6160                     NaN
# 01/04/1965    1.8630   127.3520                     NaN
# 01/05/1965  -20.5790  -173.9720                     NaN
# 01/08/1965  -59.0760   -23.5570                     NaN
# 01/09/1965   11.9380   126.4270                     NaN
# ...              ...        ...                     ...
# 12/28/2016   38.3917  -118.8941                    40.0
# 12/28/2016   38.3777  -118.8957                    33.0
# 12/28/2016   36.9179   140.4262                     NaN
# 12/29/2016   -9.0283   118.6639                     NaN
# 12/30/2016   37.3973   141.4103                     NaN
#
# [23412 rows x 3 columns]

# %% [markdown]
# ## Removendo dados
#
# - `.drop()`: remove dados específicos, indicando index/coluna
# - `.dropna()`: remove valores faltantes (not-a-number)
# - `.fillna()`: preenche valores faltantes usando alguns métodos

# %%
help(df.fillna)
# Out:
# Help on method fillna in module pandas.core.frame:
#
# fillna(value=None, method=None, axis=None, inplace=False, limit=None, downcast=None) -> Union[ForwardRef('DataFrame'), NoneType] method of pandas.core.frame.DataFrame instance
#     Fill NA/NaN values using the specified method.
#
#     Parameters
#     ----------
#     value : scalar, dict, Series, or DataFrame
#         Value to use to fill holes (e.g. 0), alternately a
#         dict/Series/DataFrame of values specifying which value to use for
#         each index (for a Series) or column (for a DataFrame).  Values not
#         in the dict/Series/DataFrame will not be filled. This value cannot
#         be a list.
#     method : {'backfill', 'bfill', 'pad', 'ffill', None}, default None
#         Method to use for filling holes in reindexed Series
#         pad / ffill: propagate last valid observation forward to next valid
#         backfill / bfill: use next valid observation to fill gap.
#     axis : {0 or 'index', 1 or 'columns'}
#         Axis along which to fill missing values.
#     inplace : bool, default False
#         If True, fill in-place. Note: this will modify any
#         other views on this object (e.g., a no-copy slice for a column in a
#         DataFrame).
#     limit : int, default None
#         If method is specified, this is the maximum number of consecutive
#         NaN values to forward/backward fill. In other words, if there is
#         a gap with more than this number of consecutive NaNs, it will only
#         be partially filled. If method is not specified, this is the
#         maximum number of entries along the entire axis where NaNs will be
#         filled. Must be greater than 0 if not None.
#     downcast : dict, default is None
#         A dict of item->dtype of what to downcast if possible,
#         or the string 'infer' which will try to downcast to an appropriate
#         equal type (e.g. float64 to int64 if possible).
#
#     Returns
#     -------
#     DataFrame or None
#         Object with missing values filled or None if ``inplace=True``.
#
#     See Also
#     --------
#     interpolate : Fill NaN values using interpolation.
#     reindex : Conform object to new index.
#     asfreq : Convert TimeSeries to specified frequency.
#
#     Examples
#     --------
#     >>> df = pd.DataFrame([[np.nan, 2, np.nan, 0],
#     ...                    [3, 4, np.nan, 1],
#     ...                    [np.nan, np.nan, np.nan, 5],
#     ...                    [np.nan, 3, np.nan, 4]],
#     ...                   columns=list('ABCD'))
#     >>> df
#          A    B   C  D
#     0  NaN  2.0 NaN  0
#     1  3.0  4.0 NaN  1
#     2  NaN  NaN NaN  5
#     3  NaN  3.0 NaN  4
#
#     Replace all NaN elements with 0s.
#
#     >>> df.fillna(0)
#         A   B   C   D
#     0   0.0 2.0 0.0 0
#     1   3.0 4.0 0.0 1
#     2   0.0 0.0 0.0 5
#     3   0.0 3.0 0.0 4
#
#     We can also propagate non-null values forward or backward.
#
#     >>> df.fillna(method='ffill')
#         A   B   C   D
#     0   NaN 2.0 NaN 0
#     1   3.0 4.0 NaN 1
#     2   3.0 4.0 NaN 5
#     3   3.0 3.0 NaN 4
#
#     Replace all NaN elements in column 'A', 'B', 'C', and 'D', with 0, 1,
#     2, and 3 respectively.
#
#     >>> values = {'A': 0, 'B': 1, 'C': 2, 'D': 3}
#     >>> df.fillna(value=values)
#         A   B   C   D
#     0   0.0 2.0 2.0 0
#     1   3.0 4.0 2.0 1
#     2   0.0 1.0 2.0 5
#     3   0.0 3.0 2.0 4
#
#     Only replace the first NaN element.
#
#     >>> df.fillna(value=values, limit=1)
#         A   B   C   D
#     0   0.0 2.0 2.0 0
#     1   3.0 4.0 NaN 1
#     2   NaN 1.0 NaN 5
#     3   NaN 3.0 NaN 4

# %%
df.fillna(method='pad').tail() #pad
# Out:
#             Latitude  Longitude  Depth Seismic Stations
# Date
# 12/28/2016   38.3917  -118.8941                    40.0
# 12/28/2016   38.3777  -118.8957                    33.0
# 12/28/2016   36.9179   140.4262                    33.0
# 12/29/2016   -9.0283   118.6639                    33.0
# 12/30/2016   37.3973   141.4103                    33.0

# %% [markdown]
# ### Análise de série temporal
#
# - sequência de informações
# - observações, modelagem, reanálise
# - eixo temporal igualmente espaçado
# - explorar inconsistências
# - corrigir
# - analisar

# %% [markdown]
# Eixo temporal (DatetimeIndex)
#
# - pacote: datetime
# - pacote: dateutil
# - pacote: pandas

# %%
# importando os pacotes
import datetime
import dateutil
import pandas as pd

# criando algumas variáveis
agora = datetime.datetime.now()

# checando o tipo de variável
print(type(agora))

agora
# Out:
# <class 'datetime.datetime'>
# datetime.datetime(2021, 11, 25, 14, 19, 3, 16900)

# %% [markdown]
# - `datetime.datetime`
# - adicionar/subtrair
# - `timedelta`

# %%
ontem = agora - datetime.timedelta(days=1)
print(ontem)

ontem = agora - datetime.timedelta(hours=24)
print(ontem)

ontem = agora - datetime.timedelta(seconds=86400)
print(ontem)
# Out:
# 2021-11-24 14:19:03.016900
# 2021-11-24 14:19:03.016900
# 2021-11-24 14:19:03.016900

# %%
amanha = agora + datetime.timedelta(days=1)
print(amanha)

amanha = agora + datetime.timedelta(hours=24)
print(amanha)

amanha = agora + datetime.timedelta(seconds=86400)
print(amanha)
# Out:
# 2021-11-26 14:19:03.016900
# 2021-11-26 14:19:03.016900
# 2021-11-26 14:19:03.016900

# %% [markdown]
# - durante análise de dados: YYYY-mm-dd HH:MM:SS
# - formatar saída
# - `.strftime()`
# - opções: https://strftime.org/

# %%
# todas as datas em decimais
print(agora.strftime('%d %B %Y %H:%M:%S'))

# # mês abreviado
print(agora.strftime('%d/%b/%Y %H:%M:%S'))

# # dia da semana
print(agora.strftime('%A'))

# # número do dia no ano 
print(agora.strftime('%j'))
# Out:
# 25 November 2021 14:19:03
# 25/Nov/2021 14:19:03
# Thursday
# 329

# %% [markdown]
# - `10 Jan 2001 13:15:00`
# - datetime não converte
# - `dateutil.parser.parse`
# - documentação: https://dateutil.readthedocs.io/en/stable/

# %%
data_baguncada = '10 Jan 2001 13:15:00'

# datetime.datetime(data_baguncada)

# %%
data = dateutil.parser.parse(data_baguncada)

print(type(data_baguncada))
print(type(data))
print(data)
# Out:
# <class 'str'>
# <class 'datetime.datetime'>
# 2001-01-10 13:15:00

# %% [markdown]
# ## Mas como trabalhar com datas em uma série temporal longa?
#
# - pandas: ferramentas internas
# - depende do arquivo
# - Nos dados de terremoto podemos utilizar dois métodos:
#     - conversão do date + time: 01/02/1965 	13:44:18

# %%
# leitura do arquivo
df = pd.read_csv('../Dados/database.csv',
                 usecols=[0,1],
                skiprows=np.arange(3000,23413))

df.head()
# Out:
#          Date      Time
# 0  01/02/1965  13:44:18
# 1  01/04/1965  11:29:49
# 2  01/05/1965  18:05:58
# 3  01/08/1965  18:49:43
# 4  01/09/1965  13:32:50

# %% [markdown]
# Conveter: Date + Time

# %%
# extraindo primeira linha para visualização apenas
linha1 = df.iloc[0:1]
linha1
# Out:
#          Date      Time
# 0  01/02/1965  13:44:18

# %%
t = linha1['Date'][0] + ' ' + linha1['Time'][0]
t
# dateutil.parser.parse(t)
# Out:
# '01/02/1965 13:44:18'

# %%
# funcao: será utilizada no date_parser
def date_parse(x, y):
    return pd.datetime.strptime(f"{x} {y}", '%m/%d/%Y %H:%M:%S')

# podemos usar funções lambda
# date_parse = lambda x: pd.datetime.strptime(x, '%Y %m %d %H %M')

df = pd.read_csv('../Dados/database.csv',
                skiprows=np.arange(3000,23413),
                parse_dates={'datetime': ['Date', 'Time']},
                date_parser=date_parse,
                 )

df.head()
# Out:
#              datetime  Latitude  Longitude        Type  Depth  Depth Error  \
# 0 1965-01-02 13:44:18    19.246    145.616  Earthquake  131.6      -9999.0
# 1 1965-01-04 11:29:49     1.863    127.352  Earthquake   80.0      -9999.0
# 2 1965-01-05 18:05:58   -20.579   -173.972  Earthquake   20.0      -9999.0
# 3 1965-01-08 18:49:43   -59.076    -23.557  Earthquake   15.0      -9999.0
# 4 1965-01-09 13:32:50    11.938    126.427  Earthquake   15.0      -9999.0
#
#    Depth Seismic Stations  Magnitude Magnitude Type  Magnitude Error  \
# 0                 -9999.0        6.0             MW          -9999.0
# 1                 -9999.0        5.8             MW          -9999.0
# 2                 -9999.0        6.2             MW          -9999.0
# 3                 -9999.0        5.8             MW          -9999.0
# 4                 -9999.0        5.8             MW          -9999.0
#
#    Magnitude Seismic Stations  Azimuthal Gap  Horizontal Distance  \
# 0                     -9999.0        -9999.0              -9999.0
# 1                     -9999.0        -9999.0              -9999.0
# 2                     -9999.0        -9999.0              -9999.0
# 3                     -9999.0        -9999.0              -9999.0
# 4                     -9999.0        -9999.0              -9999.0
#
#    Horizontal Error  Root Mean Square            ID  Source Location Source  \
# 0           -9999.0           -9999.0  ISCGEM860706  ISCGEM          ISCGEM
# 1           -9999.0           -9999.0  ISCGEM860737  ISCGEM          ISCGEM
# 2           -9999.0           -9999.0  ISCGEM860762  ISCGEM          ISCGEM
# 3           -9999.0           -9999.0  ISCGEM860856  ISCGEM          ISCGEM
# 4           -9999.0           -9999.0  ISCGEM860890  ISCGEM          ISCGEM
#
#   Magnitude Source     Status
# 0           ISCGEM  Automatic
# 1           ISCGEM  Automatic
# 2           ISCGEM  Automatic
# 3           ISCGEM  Automatic
# 4           ISCGEM  Automatic

# %% [markdown]
# #### Notem:
#
# - nova coluna
# - antigas colunas de tempo não existem mais

# %%
# agora podemos converter nossa coluna datetime em index
df.set_index('datetime', inplace=True)

df.head()
# Out:
#                      Latitude  Longitude        Type  Depth  Depth Error  \
# datetime
# 1965-01-02 13:44:18    19.246    145.616  Earthquake  131.6      -9999.0
# 1965-01-04 11:29:49     1.863    127.352  Earthquake   80.0      -9999.0
# 1965-01-05 18:05:58   -20.579   -173.972  Earthquake   20.0      -9999.0
# 1965-01-08 18:49:43   -59.076    -23.557  Earthquake   15.0      -9999.0
# 1965-01-09 13:32:50    11.938    126.427  Earthquake   15.0      -9999.0
#
#                      Depth Seismic Stations  Magnitude Magnitude Type  \
# datetime
# 1965-01-02 13:44:18                 -9999.0        6.0             MW
# 1965-01-04 11:29:49                 -9999.0        5.8             MW
# 1965-01-05 18:05:58                 -9999.0        6.2             MW
# 1965-01-08 18:49:43                 -9999.0        5.8             MW
# 1965-01-09 13:32:50                 -9999.0        5.8             MW
#
#                      Magnitude Error  Magnitude Seismic Stations  \
# datetime
# 1965-01-02 13:44:18          -9999.0                     -9999.0
# 1965-01-04 11:29:49          -9999.0                     -9999.0
# 1965-01-05 18:05:58          -9999.0                     -9999.0
# 1965-01-08 18:49:43          -9999.0                     -9999.0
# 1965-01-09 13:32:50          -9999.0                     -9999.0
#
#                      Azimuthal Gap  Horizontal Distance  Horizontal Error  \
# datetime
# 1965-01-02 13:44:18        -9999.0              -9999.0           -9999.0
# 1965-01-04 11:29:49        -9999.0              -9999.0           -9999.0
# 1965-01-05 18:05:58        -9999.0              -9999.0           -9999.0
# 1965-01-08 18:49:43        -9999.0              -9999.0           -9999.0
# 1965-01-09 13:32:50        -9999.0              -9999.0           -9999.0
#
#                      Root Mean Square            ID  Source Location Source  \
# datetime
# 1965-01-02 13:44:18           -9999.0  ISCGEM860706  ISCGEM          ISCGEM
# 1965-01-04 11:29:49           -9999.0  ISCGEM860737  ISCGEM          ISCGEM
# 1965-01-05 18:05:58           -9999.0  ISCGEM860762  ISCGEM          ISCGEM
# 1965-01-08 18:49:43           -9999.0  ISCGEM860856  ISCGEM          ISCGEM
# 1965-01-09 13:32:50           -9999.0  ISCGEM860890  ISCGEM          ISCGEM
#
#                     Magnitude Source     Status
# datetime
# 1965-01-02 13:44:18           ISCGEM  Automatic
# 1965-01-04 11:29:49           ISCGEM  Automatic
# 1965-01-05 18:05:58           ISCGEM  Automatic
# 1965-01-08 18:49:43           ISCGEM  Automatic
# 1965-01-09 13:32:50           ISCGEM  Automatic

# %% [markdown]
# ### Criando eixo temporal do zero
#
# - data de início
# - data final
# - frequência temporal
# - `pd.date_range()`

# %%
# frequência horária, diária, mensal
eixo_temporal_metodo1 = pd.date_range(start='2020-10-20 00', 
                              end='2020-11-20 00',
                              freq='5D')

eixo_temporal_metodo2 = pd.date_range(start='2021-07-15 00:00', periods=180, freq='1D')

eixo_temporal_metodo1
# Out:
# DatetimeIndex(['2020-10-20', '2020-10-25', '2020-10-30', '2020-11-04',
#                '2020-11-09', '2020-11-14', '2020-11-19'],
#               dtype='datetime64[ns]', freq='5D')

# %% [markdown]
# ## Exemplo
#
# ### Conjunto de dados do IBAMA: localidades afetadas pela mancha de óleo em 2019
#
# - Vamos fazer leitura de arquivo excel
# - limpar e ajustar do conjunto de dados

# %%
# leitura do arquivo
url = "http://www.ibama.gov.br/phocadownload/emergenciasambientais/2019/manchasdeoleo/2019-12-02_LOCALIDADES_AFETADAS.xlsx"
df = pd.read_excel(
                    url,
                    parse_dates=["Data_Avist", "Data_Revis"],
                  )
df
# Out:
#      geocodigo           localidade      loc_id           municipio  \
# 0      3201605      Praia de Guriri  3201605_43  Conceição da Barra
# 1      3201605      Praia de Guriri  3201605_46  Conceição da Barra
# 2      3201605      Praia de Guriri  3201605_45  Conceição da Barra
# 3      2207702      Praia do Pontal   2207702_4            Parnaíba
# 4      3202405       Praia do Morro  3202405_39           Guarapari
# ..         ...                  ...         ...                 ...
# 861    3203205    Praia de Povoação  3203205_61            Linhares
# 862    3201605  Praia Pontal do Sul  3201605_40  Conceição da Barra
# 863    3201605  Praia Pontal do Sul  3201605_42  Conceição da Barra
# 864    3201605  Praia Pontal do Sul  3201605_41  Conceição da Barra
# 865    3201605      Praia de Guriri  3201605_44  Conceição da Barra
#
#              estado sigla_uf Data_Avist Data_Revis  \
# 0    Espírito Santo       ES 2019-11-23 2019-11-23
# 1    Espírito Santo       ES 2019-11-18 2019-11-19
# 2    Espírito Santo       ES 2019-11-21 2019-11-27
# 3             Piauí       PI 2019-11-08 2019-11-17
# 4    Espírito Santo       ES 2019-11-28 2019-11-28
# ..              ...      ...        ...        ...
# 861  Espírito Santo       ES 2019-11-18 2019-11-23
# 862  Espírito Santo       ES 2019-11-14 2019-11-30
# 863  Espírito Santo       ES 2019-11-16 2019-11-18
# 864  Espírito Santo       ES 2019-11-26 2019-11-26
# 865  Espírito Santo       ES 2019-11-22 2019-11-22
#
#                             Status          Latitude         Longitude
# 0    Oleada - Vestigios / Esparsos  18° 40' 43.70" S  39° 44' 33.69" W
# 1    Oleada - Vestigios / Esparsos  18° 42' 14.87" S  39° 44' 45.92" W
# 2    Oleada - Vestigios / Esparsos  18° 41' 54.57" S  39° 44' 40.31" W
# 3    Oleada - Vestigios / Esparsos   2° 45' 46.58" S  41° 46' 54.03" W
# 4    Oleada - Vestigios / Esparsos  20° 39' 18.19" S  40° 28' 42.74" W
# ..                             ...               ...               ...
# 861  Oleada - Vestigios / Esparsos  19° 31' 6.060" S  39° 45' 11.32" W
# 862  Oleada - Vestigios / Esparsos  18° 39' 5.425" S  39° 44' 18.42" W
# 863  Oleada - Vestigios / Esparsos  18° 40' 3.646" S  39° 44' 30.02" W
# 864  Oleada - Vestigios / Esparsos  18° 39' 38.00" S  39° 44' 24.91" W
# 865  Oleada - Vestigios / Esparsos  18° 41' 16.86" S  39° 44' 35.65" W
#
# [866 rows x 11 columns]

# %% [markdown]
# **Vamos tentar fazer algumas coisasinhas aqui:**
#
# - Utilizando groupby, count e plot, monte um gráfico de barras e responda: qual o Estado mais afetado segundo o conjunto de dados?

# %%
# Calculando o tempo de permanência da mancha em cada localidade
df["dias"] = (df["Data_Revis"] - df["Data_Avist"]).dt.days

# %%
# tratando as colunas de tempo
df['Data_Avist'] = df['Data_Avist'].dt.strftime('%Y-%m-%d').str.replace('NaT', 'na')
df["Data_Revis"] = df["Data_Revis"].dt.strftime("%Y-%m-%d").str.replace("NaT", "na")
df["dias"] = df["dias"].astype('Int64').astype(str).str.replace("nan", "na")

# %%
df.dropna(inplace=True)
df.head()
# Out:
#    geocodigo       localidade      loc_id           municipio          estado  \
# 0    3201605  Praia de Guriri  3201605_43  Conceição da Barra  Espírito Santo
# 1    3201605  Praia de Guriri  3201605_46  Conceição da Barra  Espírito Santo
# 2    3201605  Praia de Guriri  3201605_45  Conceição da Barra  Espírito Santo
# 3    2207702  Praia do Pontal   2207702_4            Parnaíba           Piauí
# 4    3202405   Praia do Morro  3202405_39           Guarapari  Espírito Santo
#
#   sigla_uf  Data_Avist  Data_Revis                         Status  \
# 0       ES  2019-11-23  2019-11-23  Oleada - Vestigios / Esparsos
# 1       ES  2019-11-18  2019-11-19  Oleada - Vestigios / Esparsos
# 2       ES  2019-11-21  2019-11-27  Oleada - Vestigios / Esparsos
# 3       PI  2019-11-08  2019-11-17  Oleada - Vestigios / Esparsos
# 4       ES  2019-11-28  2019-11-28  Oleada - Vestigios / Esparsos
#
#            Latitude         Longitude dias
# 0  18° 40' 43.70" S  39° 44' 33.69" W    0
# 1  18° 42' 14.87" S  39° 44' 45.92" W    1
# 2  18° 41' 54.57" S  39° 44' 40.31" W    6
# 3   2° 45' 46.58" S  41° 46' 54.03" W    9
# 4  20° 39' 18.19" S  40° 28' 42.74" W    0

# %%
# um pouco de limpeza de dados (data cleaning)

# removendo linhas onde o status == nao observado
filtr = (df['Status'] == 'Oleo Nao Observado')
df = df[~filtr].copy()

# removendo registros onde o dias == 0
filtr = (df['dias'] == 0)
df = df[~filtr].copy()

df.head()
# Out:
#    geocodigo       localidade      loc_id           municipio          estado  \
# 0    3201605  Praia de Guriri  3201605_43  Conceição da Barra  Espírito Santo
# 1    3201605  Praia de Guriri  3201605_46  Conceição da Barra  Espírito Santo
# 2    3201605  Praia de Guriri  3201605_45  Conceição da Barra  Espírito Santo
# 3    2207702  Praia do Pontal   2207702_4            Parnaíba           Piauí
# 4    3202405   Praia do Morro  3202405_39           Guarapari  Espírito Santo
#
#   sigla_uf  Data_Avist  Data_Revis                         Status  \
# 0       ES  2019-11-23  2019-11-23  Oleada - Vestigios / Esparsos
# 1       ES  2019-11-18  2019-11-19  Oleada - Vestigios / Esparsos
# 2       ES  2019-11-21  2019-11-27  Oleada - Vestigios / Esparsos
# 3       PI  2019-11-08  2019-11-17  Oleada - Vestigios / Esparsos
# 4       ES  2019-11-28  2019-11-28  Oleada - Vestigios / Esparsos
#
#            Latitude         Longitude dias
# 0  18° 40' 43.70" S  39° 44' 33.69" W    0
# 1  18° 42' 14.87" S  39° 44' 45.92" W    1
# 2  18° 41' 54.57" S  39° 44' 40.31" W    6
# 3   2° 45' 46.58" S  41° 46' 54.03" W    9
# 4  20° 39' 18.19" S  40° 28' 42.74" W    0

# %% [markdown]
# ### Agrupamento (groupby)
#
# - chaves (keys): grupos
# - eixo (axis, 0 para linhas, 1 para colunas)
# - método estatístico a ser utilizado no agrupamento (sum, mean, max, min, etc)

# %%
# Estado mais afetado
df.groupby('sigla_uf').count()['estado'].plot(kind='barh')

# %% [markdown]
# - Da mesma forma, mas sem necessidade de figura, agrupe por Município e apresente quais foram os 10 mais afetados

# %%
# Município mais afetado
df.groupby('municipio').count()\
        .sort_values(by='dias', 
                     ascending=False)\
        .head(10)
# Out:
#                     geocodigo  localidade  loc_id  estado  sigla_uf  \
# municipio
# São Mateus                 29          29      29      29        29
# Ilhéus                     22          22      22      22        22
# Conceição da Barra         21          21      21      21        21
# Aracaju                    20          20      20      20        20
# Linhares                   19          19      19      19        19
# Prado                      19          19      19      19        19
# Piaçabuçu                  19          19      19      19        19
# Porto Seguro               18          18      18      18        18
# Estância                   18          18      18      18        18
# Maraú                      17          17      17      17        17
#
#                     Data_Avist  Data_Revis  Status  Latitude  Longitude  dias
# municipio
# São Mateus                  29          29      29        29         29    29
# Ilhéus                      22          22      22        22         22    22
# Conceição da Barra          21          21      21        21         21    21
# Aracaju                     20          20      20        20         20    20
# Linhares                    19          19      19        19         19    19
# Prado                       19          19      19        19         19    19
# Piaçabuçu                   19          19      19        19         19    19
# Porto Seguro                18          18      18        18         18    18
# Estância                    18          18      18        18         18    18
# Maraú                       17          17      17        17         17    17

# %% [markdown]
# - Filtre o conjunto de dados para identificar as primeiras e últimas localidades afetadas.

# %%
# primeiros e ultimos afetados
# filtr = (df['Data_Avist'] == df.min()['Data_Avist'])
# df[filtr].head(5)

df[df['Data_Revis'] == df.max()['Data_Revis']].sort_values(by='dias', ascending=False).head(5)
# Out:
#      geocodigo            localidade      loc_id     municipio  \
# 215    2414209         Praia do Amor   2414209_5  Tibau do Sul
# 209    2800308               Atalaia   2800308_9       Aracaju
# 578    2910602  Foz do Rio Inhampube  2910602_11     Esplanada
# 202    2800308    Praia dos Artistas   2800308_6       Aracaju
# 125    2914901      Praia da Ribeira   2914901_7       Itacaré
#
#                   estado sigla_uf  Data_Avist  Data_Revis  \
# 215  Rio Grande do Norte       RN  2019-09-10  2019-12-02
# 209              Sergipe       SE  2019-10-02  2019-12-02
# 578                Bahia       BA  2019-10-07  2019-12-02
# 202              Sergipe       SE  2019-10-29  2019-12-02
# 125                Bahia       BA  2019-10-30  2019-12-02
#
#                             Status          Latitude         Longitude dias
# 215  Oleada - Vestigios / Esparsos   6° 13' 44.49" S   35° 2' 34.26" W   83
# 209  Oleada - Vestigios / Esparsos  10° 58' 55.88" S   37° 2' 14.16" W   61
# 578  Oleada - Vestigios / Esparsos   12° 5' 59.78" S  37° 41' 11.97" W   56
# 202  Oleada - Vestigios / Esparsos  10° 58' 26.94" S   37° 1' 52.02" W   34
# 125  Oleada - Vestigios / Esparsos  14° 17' 27.58" S  38° 58' 59.51" W   33

# %% [markdown]
# - Por fim, qual a localidade afetada por mais tempo?

# %%
# afetados por mais tempo
df['localidade'] = df['localidade'].astype(str)
df['dias'] = df['dias'].astype(int)

df.groupby(by='localidade').sum().sort_values('dias', ascending=False)[['dias']].head(5)
# Out:
#                     dias
# localidade
# Praia da Costa       148
# Atalaia              113
# Praia de Flexeiras   108
# Praia de Jatobá       97
# Atalaia Nova          90
